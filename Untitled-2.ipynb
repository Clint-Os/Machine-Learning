# %% [markdown]
# DEEP COMPUTER VISION USING CONVOLUTED NEURAL NETWORKS

# %% [markdown]
# Tensorflow Implementation

# %% [markdown]
# Let's load two inbuilt sample images, (chinese temple and a flower). Pixel intensities for each color channel is represented as a byte from 0-255, thus we scale these features by dividing  by 255 to get floats ranging from 0-1. We then create two 7x7 filters (one with a vertical middle white line and the other horizontal) and then apply to both images. We will use zero padding and a stride of 2 then plot one of the rsulting feature maps.

# %%
import sklearn 
import tensorflow as tf
from tensorflow import keras 

import numpy as np
import os 

np.random.seed(42)
tf.random.set_seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

#To plot greyscale and RGB images:

def plot_image(image):
    plt.imshow(image, cmap="gray", interpolation="nearest")
    plt.axis("off")

def plot_color_image(image):
    plt.imshow(image, interpolation="nearest")
    plt.axis("off")

# %%
from sklearn.datasets import load_sample_image 

china = load_sample_image("china.jpg")/255
flower = load_sample_image("flower.jpg")/255
images = np.array([china, flower])  #the input minibatch 
batch_size, height, width, channels = images.shape  #specify the 4D tensor shape of the filters

# %%
#create 2 filters 

filters = np.zeros(shape = (7, 7, channels, 2), dtype = np.float32)
filters[:, 3, :, 0] = 1 #vertical line
filters[3, :, :, 1] = 1 #horizontal line 

# The weights of a convolutional layer are represented as a 4D tensor of shape [fh, fw, fn′, fn]

# %% [markdown]
# • images is the input mini-batch (a 4D tensor, as explained earlier).
#
# • filters is the set of filters to apply (also a 4D tensor, as explained earlier).
#
# • strides is equal to 1, but it could also be a 1D array with 4 elements, where the two central elements are the vertical and horizontal strides (sh and sw). The first and last elements must currently be equal to 1. They may one day be used to specify a batch stride (to skip some instances) and a channel stride (to skip some of the previous layer’s feature maps or channels)

# %%
outputs = tf.nn.conv2d(images, filters, strides = 1, padding = "SAME") #Computes a 2-D convolution given input and 4-D filters tensors.


plt.imshow(outputs[0, :, :, 1], cmap = "gray") #plots the first image's 2nd feature map 
plt.show()

# %%
for image_index in (0,1):
    for feature_map_index in (0,1):
        plt.subplot(2, 2, image_index * 2 + feature_map_index + 1)
        plot_image(outputs[image_index, :,:, feature_map_index])

plt.show()

# %%
def crop(images):
    return images[150:220, 130:250] #slicing rows and columns to obtain a sample rectangle image

# %%
plot_image(crop(images[0, :, :, 0]))
plt.show()


for feature_map_index, filename in enumerate (["china_vertical", "china_horizontal"]):
    plot_image(crop(outputs[0, :, :, feature_map_index]))
    plt.show()
#batch size, height, width, channel

# %%
plot_image(filters[:, :, 0, 0])  #slices the filter tensor to get the first filter corresonding to the first input channel and first output channel 
#filters function contains weights of the convolutional filters from the convolutional layer, with the shape of [fh, fw, fn′, fn] i.e (filter_height, filter_width, inpput_channels, output_channels)
plt.show()

plot_image(filters[:, :, 0, 1]) #to obtain the first filter that corresponds with the first inut_chanel, and second_output channel 

plt.show()

# %% [markdown]
# Convolutional Layer
#
#     :- create a 2D convolutional layer, using keras.layers.Conv2D():

# %%
conv = keras.layers.Conv2D(filters= 2, kernel_size = 7, strides = 1, padding = "SAME", activation = "relu", input_shape = outputs.shape)
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#call the layer and pass it the two test images:

conv_outputs = conv(images)
conv_outputs.shape
# Out:
# TensorShape([2, 427, 640, 2])

# %% [markdown]
# The output is a 4D tensor. The batch size is 2, bc there are 2 test images, then height and width of the output feature maps since padding s same and stride is 1, the output feature maps have the same shape as input images. Lastly, 2 filters means there are 2 output feature maps per input image, as shown by the shape.

# %% [markdown]
# Pooling Layer

# %% [markdown]
# Max pooling

# %%
#create a max pooling layer  using a 2x2 kernel, with a default stride of 2

max_pool = keras.layers.MaxPool2D(pool_size = 2)

# %% [markdown]
# max pooling can be done along the depth dimension rather than the spatial dimensions to allow CNN to learn to be invariant to various feature e.g thickness, brightness, skew, color etc

# %% [markdown]
# Depth-wise pooling

# %%
output = tf.nn.max_pool (images, ksize= [1, 1, 1, 3], strides = [1, 1, 1, 3], padding = "VALID")

#keras lacks a depth-wise max pooling layer so we use TF's low-level deep learning API
#last value can be whatever kernel size and stride desired as long as its a divisor of the input depth

# %%
#wrap it in a lambda layer or create a ccustom layer

depth_pool =keras.layers.Lambda( lambda x: tf.nn.max_pool(X, ksize= (1,1,1,3), strides = (1,1,1,3), padding = "VALID"))

# %% [markdown]
# Global average pooling
#
# -: it computes the mean of entire feature map thus outputs a single number per feature map and per instance (though this is destructive, it can be useful as the output layer)

# %%
global_avg_pool = keras.layers.GlobalAvgPool2D()

cropped_images = np.array([crop(image) for image in images], dtype= np.float32)
global_avg_pool(cropped_images)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[0.2788801 , 0.22507527, 0.20967631],
#        [0.51287866, 0.4595188 , 0.3342377 ]], dtype=float32)>

# %% [markdown]
# CNN Architectures

# %% [markdown]
# Implementing CNN using fashion MNIST dataset

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

X_train, X_valid = X_train_full[: -50000], X_train_full[-50000:]
y_train, y_valid, = y_train_full[:-50000], y_train_full[-50000:]

X_mean = X_train.mean(axis=0, keepdims = True)
X_std = X_train.std(axis=0, keepdims = True) + 1e-7
X_train = (X_train - X_mean) / X_std
X_valid = (X_valid - X_mean) / X_std
X_test = (X_test - X_mean)/ X_std 

X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test [..., np.newaxis]

# %%
from functools import partial

DefaultConv2D = partial(keras.layers.Conv2D,
                        kernel_size=3, activation='relu', padding="SAME")

model = keras.models.Sequential([
    DefaultConv2D(filters=64, kernel_size=7, input_shape=[28, 28, 1]),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=10, activation='softmax'),
])

# %% [markdown]
# -> The partial() function defines a thin wrapper around the DefaultConv2D class, to avoid repeating the ame hyperparameter values over and over again.
#
# -> The first layer uses a large kernel , but no stride bc the input images are not very large. The input shape means 28X28 pixels with a single color channel - grayscale
# -> Then the Maxpooling layer divides each spatial dimension by a factor of two
# -> Repeat the same structure twice: 2 convolutional layer followed by a max pooling layer
#
# -> The number of filters grows as we climb up the CNN towards the output layer (64,128,256), it grows since thenumber of low level features is often low (small circles, horizontal lines etc)
# -> Next is the fully connected network with 2 hidden Dense layers and a dense output layer. The inputs must be flattened since a dense network expects a 1D array of features for each instance. The two dropout layers with a rate of 50% are included to reduce overfitting.

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer = "nadam", metrics =["accuracy"])

history = model.fit(X_train, y_train, epochs = 10, validation_data = (X_valid, y_valid))
score = model.evaluate(X_test, y_test)
X_new = X_test[: 10]  #assume we have new images
y_pred = model.predict(X_new)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 249ms/step - accuracy: 0.4030 - loss: 1.6262 - val_accuracy: 0.7689 - val_loss: 0.6664
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 69s 220ms/step - accuracy: 0.7123 - loss: 0.7853 - val_accuracy: 0.7893 - val_loss: 0.5846
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 225ms/step - accuracy: 0.7696 - loss: 0.6357 - val_accuracy: 0.8151 - val_loss: 0.5239
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 230ms/step - accuracy: 0.8025 - loss: 0.5424 - val_accuracy: 0.8335 - val_loss: 0.4850
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 67s 214ms/step - accuracy: 0.8281 - loss: 0.4929 - val_accuracy: 0.8539 - val_loss: 0.4378
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 234ms/step - accuracy: 0.8534 - loss: 0.4373 - val_accuracy: 0.8313 - val_loss: 0.4790
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 69s 220ms/step - accuracy: 0.8566 - loss: 0.4142 - val_accuracy: 0.8725 - val_loss: 0.3929
# Epoch 8/10
# ...

# %% [markdown]
# CNN ARCHITECTURES

# %% [markdown]
# ResNet-34 using Keras

# %%
import tensorflow as tf
from tensorflow import keras



DefaultConv2D = partial(keras.layers.Conv2D,kernel_size =3, strides = 1, padding  = "SAME", use_bias=False)

class ResidualUnit(keras.layers.Layer):
    def __init__(self, filters, strides = 1, activation ="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.main_layers = [
            DefaultConv2D(filters, strides = strides),
            keras.layers.BatchNormalization(),
            self.activation,
            DefaultConv2D(filters),
            keras.layers.BatchNormalization(),]
        self.skip_layers = []
        if strides >1:
            self.skip_layers = [
                DefaultConv2D(filters, kernel_size = 1, strides = strides),
                keras.layers.BatchNormalization(),
            ]
        
    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        for layer in self.skip_layers:
            skip_Z=layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
model = keras.models.Sequential()
model.add(DefaultConv2D(64, kernel_size=7, strides=2,
                        input_shape=[224, 224, 3]))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation("relu"))
model.add(keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same"))
prev_filters = 64
for filters in [64] * 3 + [128] * 4 + [256] * 6 + [512] * 3:
    strides = 1 if filters == prev_filters else 2
    model.add(ResidualUnit(filters, strides=strides))
    prev_filters = filters
model.add(keras.layers.GlobalAvgPool2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:From c:\Users\user\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\layer.py:1295: UserWarning: Layer 'residual_unit' looks like it has unbuilt state, but Keras is not able to trace the layer `call()` in order to build it automatically. Possible causes:
# 1. The `call()` method of your layer may be crashing. Try to `__call__()` the layer eagerly on some test input first to see if it works. E.g. `x = np.random.random((3, 4)); y = layer(x)`
# ...

# %% [markdown]
# Using Pretrained models from Keras

# %% [markdown]
# Training a model to classify picures of flowers, reusing a pretrained Xception model

# %%
import tensorflow_datasets as tfds

dataset, info  = tfds.load("tf_flowers", as_supervised = True, with_info = True)
dataset_size = info.splits['train'].num_examples #3670
class_names = info.features['label'].names
n_classes = info.features['label'].num_classes #5

# %%
#use split API to split the dataset to test, train and validation 

test_set_raw, valid_set_raw, train_set_raw = tfds.load('tf_flowers', split = ['train[:10%]', 'train[10%:25%]', 'train[25%:]'], as_supervised = True)

# %%
plt.figure(figsize=(12,10))
index = 0
for image, label in train_set_raw.take(9):
    index += 1
    plt.subplot(3, 3, index)
    plt.imshow(image)
    plt.title(class_names[label.numpy()])
    plt.axis("off")

# %% [markdown]
# Preprocess the images next. The CNN expects 224X224 images, so they need to be resized the run the mage through Xception's preprocess_input()function

# %%
def preprocess(image, label):
    resized_image = tf.image.resize(image,[224,224])
    final_image = keras.applcations.xception.preprocess_input(resized_image)
    return final_image, label

# %%
#apply the function to all the 3 datasets and shuffle them, repeat the training set and add batching and prefetching to all datasets
batch_size  = 32
train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(preprocess).batch(batch_size).prefetch(1)

valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
#       2 batch_size  = 32
#       3 train_set = train_set_raw.shuffle(1000).repeat()
# ----> 4 train_set = train_set.map(preprocess).batch(batch_size).prefetch(1)
#       6 valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
#       7 test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)
#
# File c:\Users\user\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2299, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2295 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2296 # dataset_ops).
#    2297 # pylint: disable=g-import-not-at-top,protected-access
#    2298 from tensorflow.python.data.ops import map_op
# -> 2299 return map_op._map_v2(
#    2300     self,
#    2301     map_func,
# ...

# %%
#load an xception model and exclude the top of the network thus excluding global avg pooling layer and the dense output layer

base_model = keras.applications.Xception(weights = "imagenet", include_top = False)

#add our own avg layer and dense output layer
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(n_classes, activation = "softmax")(avg)

#createthe keras model 
model = keras.models.Model(base_model.input, output)
# Out:
# ...
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 334s 4us/step

# %%
#freeze the weights of the pretrained layers at the beginning of the training

for layer in base_model.layers:
    layer.trainable = False

# %%
#compile and start training

optimizer = keras.optimizers.SGD(learning_rate = 0.2, momentum = 0.9, decay = 0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer = optimizer, metrics = ["accuracy"])

history = model.fit(train_set, steps_per_epoch = int(0.75* dataset_size/batch_size), epochs= 5, validation_data = valid_set, validation_steps = int(0.15* dataset_size/batch_size))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       3 optimizer = keras.optimizers.SGD(learning_rate = 0.2, momentum = 0.9, decay = 0.01)
#       5 model.compile(loss="sparse_cattegorical_crossentropy", optimizer = optimizer, metrics = ["accuracy"])
# ----> 7 history = model.fit(train_set, steps_per_epoch = int(0.75* dataset_size/batch_size), epochs= 5, validation_data = valid_set, validation_steps = int(0.15* dataset_size/batch_size))
#
# NameError: name 'valid_set' is not defined

# %% [markdown]
# After training the model, once the validation accuracy stops making much progress, it means the top layers are now well trained. We can the unfreeze all the layers or just the top ones and continue training (remember to compile the model when freezing or unfreezing layers).

# %%
#use a lower learning rate to avoid damage to the pretrained weights 
for layer in base_model.layers:
    layer.trainable = True 

optimizer = keras.optimizers.SGD(learning_rate = 0.01, momentum = 0.9, neterov=True, decay = 0.001)

model.compile(loss="sparse_categrorical_crossentropy", optimizer = optimizer, metrics = ["accuracy"])

history = model.fit(train_set, steps_per_epoch = int(0.75* dataset_size/batch_size), epochs= 40, validation_data = valid_set, validation_steps = int(0.15* dataset_size/batch_size))

# %% [markdown]
# Classification and Localization

# %% [markdown]
# Localization of an object in a picture is a regression  task
#
# With 4 numbers to predict (horizontal, vertical corrdinates and height and width), we do not change the model much, we will add a second output layer with 4 units, and it can be trained using the MSE loss:

# %%
base_model = keras.applications.Xception(weights = "imagenet", include_top = False)

avg = keras.layers.GlobalAveragePooling2D()(base_model.output)

class_output = keras.layers.Dense(n_classes, activation = "softmax")(avg)

loc_output = keras.layers.Dense(4)(avg)

# %%
model  = keras.models.Model(inputs = base_model.input, outputs = [class_output, loc_output])

model.compile(loss=["sparse_categorical_crossentropy", "mse"], loss_weights=[0.8, 0.2], optimizer = keras.optimizers.SGD(learning_rate = 0.2, momentum = 0.9, decay = 0.01), metrics  = ["accuracy"])
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\keras\src\optimizers\base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %% [markdown]
# The flower dataset lacks bounding boxes around the, hence we add them ourselves. You can use an open source image labeling tool e.g. VGG Image Annotator, LabelImg, or even ImgLab etc

# %%
def add_random_bounding_boxes(images, labels):
    fake_bboxes = tf.random.uniform([tf.shape(images)[0],4])
    return images, (labels, fake_bboxes)

fake_train_set = train_set.take(5).repeat(2).map(add_random_bounding_boxes)

# %%
# model.fit(fake_train_set, steps_per_epoch = 5, epochs = 2)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
